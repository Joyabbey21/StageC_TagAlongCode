# %% [markdown]
# <a href="https://colab.research.google.com/github/Joyabbey21/StageC_TagAlongCode/blob/main/Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# **Request page source from URL**

# %%
url = "https://www.imdb.com/chart/top/"

# %%
page = requests.get(url)
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content, "html.parser")
# print(soup.prettify())

# %%
# scrap movie names
scraped_movies = soup.find_all('td', class_='titleColumn')
scraped_movies
# Out:
# [<td class="titleColumn">
#        1.
#        <a href="/title/tt0111161/" title="Frank Darabont (dir.), Tim Robbins, Morgan Freeman">The Shawshank Redemption</a>
#  <span class="secondaryInfo">(1994)</span>
#  </td>, <td class="titleColumn">
#        2.
#        <a href="/title/tt0068646/" title="Francis Ford Coppola (dir.), Marlon Brando, Al Pacino">The Godfather</a>
#  <span class="secondaryInfo">(1972)</span>
#  </td>, <td class="titleColumn">
#        3.
#        <a href="/title/tt0468569/" title="Christopher Nolan (dir.), Christian Bale, Heath Ledger">The Dark Knight</a>
#  <span class="secondaryInfo">(2008)</span>
#  </td>, <td class="titleColumn">
#        4.
#        <a href="/title/tt0071562/" title="Francis Ford Coppola (dir.), Al Pacino, Robert De Niro">The Godfather Part II</a>
#  <span class="secondaryInfo">(1974)</span>
#  </td>, <td class="titleColumn">
#        5.
# ...

# %%
# parse movie names
movies = []
for movie in scraped_movies:
    movie = movie.get_text().replace('\n', "")
    movie = movie.strip(" ")
    movies.append(movie)
movies
# Out:
# ['1.      The Shawshank Redemption(1994)',
#  '2.      The Godfather(1972)',
#  '3.      The Dark Knight(2008)',
#  '4.      The Godfather Part II(1974)',
#  '5.      12 Angry Men(1957)',
#  "6.      Schindler's List(1993)",
#  '7.      The Lord of the Rings: The Return of the King(2003)',
#  '8.      Pulp Fiction(1994)',
#  '9.      The Lord of the Rings: The Fellowship of the Ring(2001)',
#  '10.      The Good, the Bad and the Ugly(1966)',
#  '11.      Forrest Gump(1994)',
#  '12.      Fight Club(1999)',
#  '13.      Inception(2010)',
#  '14.      The Lord of the Rings: The Two Towers(2002)',
#  '15.      Star Wars: Episode V - The Empire Strikes Back(1980)',
#  '16.      The Matrix(1999)',
#  '17.      Goodfellas(1990)',
#  "18.      One Flew Over the Cuckoo's Nest(1975)",
#  '19.      Se7en(1995)',
#  '20.      Seven Samurai(1954)',
#  "21.      It's a Wonderful Life(1946)",
#  '22.      The Silence of the Lambs(1991)',
#  '23.      City of God(2002)',
# ...

# %%
# scrap rating for movies
scraped_ratings = soup.find_all('td', class_='ratingColumn imdbRating')
scraped_ratings
# Out:
# [<td class="ratingColumn imdbRating">
#  <strong title="9.2 based on 2,636,628 user ratings">9.2</strong>
#  </td>, <td class="ratingColumn imdbRating">
#  <strong title="9.2 based on 1,827,436 user ratings">9.2</strong>
#  </td>, <td class="ratingColumn imdbRating">
#  <strong title="9.0 based on 2,607,915 user ratings">9.0</strong>
#  </td>, <td class="ratingColumn imdbRating">
#  <strong title="9.0 based on 1,253,216 user ratings">9.0</strong>
#  </td>, <td class="ratingColumn imdbRating">
#  <strong title="8.9 based on 778,455 user ratings">8.9</strong>
#  </td>, <td class="ratingColumn imdbRating">
#  <strong title="8.9 based on 1,337,173 user ratings">8.9</strong>
#  </td>, <td class="ratingColumn imdbRating">
#  <strong title="8.9 based on 1,811,012 user ratings">8.9</strong>
#  </td>, <td class="ratingColumn imdbRating">
#  <strong title="8.8 based on 2,017,839 user ratings">8.8</strong>
#  </td>, <td class="ratingColumn imdbRating">
# ...

# %%
# parse ratings
ratings = []
for rating in scraped_ratings:
    rating = rating.get_text().replace('\n', '')
    ratings.append(rating)
ratings
# Out:
# ['9.2',
#  '9.2',
#  '9.0',
#  '9.0',
#  '8.9',
#  '8.9',
#  '8.9',
#  '8.8',
#  '8.8',
#  '8.8',
#  '8.8',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.2',
#  '8.2',
# ...

# %%
data = pd.DataFrame()
data['Movie Names'] = movies
data['Ratings'] = ratings
data.head()
# Out:
#                               Movie Names Ratings
# 0  1.      The Shawshank Redemption(1994)     9.2
# 1             2.      The Godfather(1972)     9.2
# 2           3.      The Dark Knight(2008)     9.0
# 3     4.      The Godfather Part II(1974)     9.0
# 4              5.      12 Angry Men(1957)     8.9

# %%
data.isnull().sum()
# Out:
# Movie Names    0
# Ratings        0
# dtype: int64

# %%
data["Year"] = data["Movie Names"].apply(lambda x:x.split("(")[1])
data.head()
# Out:
#                               Movie Names Ratings   Year
# 0  1.      The Shawshank Redemption(1994)     9.2  1994)
# 1             2.      The Godfather(1972)     9.2  1972)
# 2           3.      The Dark Knight(2008)     9.0  2008)
# 3     4.      The Godfather Part II(1974)     9.0  1974)
# 4              5.      12 Angry Men(1957)     8.9  1957)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Movie Names  250 non-null    object
#  1   Ratings      250 non-null    object
#  2   Year         250 non-null    object
# dtypes: object(3)
# memory usage: 6.0+ KB

# %%
data["Year"] = data["Year"].replace(")","")
data.head()
# Out:
#                               Movie Names Ratings   Year
# 0  1.      The Shawshank Redemption(1994)     9.2  1994)
# 1             2.      The Godfather(1972)     9.2  1972)
# 2           3.      The Dark Knight(2008)     9.0  2008)
# 3     4.      The Godfather Part II(1974)     9.0  1974)
# 4              5.      12 Angry Men(1957)     8.9  1957)

# %%
yr = list(data["Year"])
all_yr = []
for x in  yr:
  val = x[:4]
  all_yr.append(val)

all_yr
# Out:
# ['1994',
#  '1972',
#  '2008',
#  '1974',
#  '1957',
#  '1993',
#  '2003',
#  '1994',
#  '2001',
#  '1966',
#  '1994',
#  '1999',
#  '2010',
#  '2002',
#  '1980',
#  '1999',
#  '1990',
#  '1975',
#  '1995',
#  '1954',
#  '1946',
#  '1991',
#  '2002',
#  '1998',
#  '1997',
#  '1999',
#  '2014',
#  '1977',
#  '1991',
#  '1985',
#  '2001',
#  '1960',
#  '2002',
#  '1994',
#  '2019',
#  '1994',
#  '2000',
#  '1998',
#  '2006',
#  '1995',
#  '2006',
#  '1942',
#  '2014',
#  '2011',
#  '1962',
#  '1988',
#  '1936',
#  '1968',
#  '1954',
#  '1979',
#  '1931',
#  '1988',
#  '1979',
#  '2000',
#  '1981',
#  '2012',
#  '2008',
#  '2006',
#  '1950',
#  '1957',
#  '1980',
#  '1940',
#  '2022',
#  '1957',
#  '2018',
#  '1986',
#  '1999',
#  '1964',
#  '2018',
#  '2012',
#  '2003',
#  '2019',
#  '1984',
#  '1995',
#  '1995',
#  '2017',
#  '2009',
#  '1981',
#  '1997',
#  '2019',
#  '1984',
#  '1997',
#  '2016',
#  '2000',
#  '2010',
#  '1952',
#  '2009',
#  '1983',
#  '1963',
#  '1968',
# ...

# %%
years = np.array(all_yr)
import numpy as np
data["Year"] = years
data.head()
# Out:
#                               Movie Names Ratings  Year
# 0  1.      The Shawshank Redemption(1994)     9.2  1994
# 1             2.      The Godfather(1972)     9.2  1972
# 2           3.      The Dark Knight(2008)     9.0  2008
# 3     4.      The Godfather Part II(1974)     9.0  1974
# 4              5.      12 Angry Men(1957)     8.9  1957

# %%
data["Movie Names"] = data["Movie Names"].apply(lambda x:x.split("(")[0])
data.head()
# Out:
#                         Movie Names Ratings  Year
# 0  1.      The Shawshank Redemption     9.2  1994
# 1             2.      The Godfather     9.2  1972
# 2           3.      The Dark Knight     9.0  2008
# 3     4.      The Godfather Part II     9.0  1974
# 4              5.      12 Angry Men     8.9  1957

# %%
df = data.copy()

# %%
data = df.copy()
data.head()
# Out:
#                         Movie Names Ratings  Year
# 0  1.      The Shawshank Redemption     9.2  1994
# 1             2.      The Godfather     9.2  1972
# 2           3.      The Dark Knight     9.0  2008
# 3     4.      The Godfather Part II     9.0  1974
# 4              5.      12 Angry Men     8.9  1957

# %%
data["Movie Names"] = data["Movie Names"].apply(lambda x:x.split(".")[1])
data.head()
# Out:
#                       Movie Names Ratings  Year
# 0        The Shawshank Redemption     9.2  1994
# 1                   The Godfather     9.2  1972
# 2                 The Dark Knight     9.0  2008
# 3           The Godfather Part II     9.0  1974
# 4                    12 Angry Men     8.9  1957

# %%
data.head(50)
# Out:
#                                           Movie Names Ratings  Year
# 0                            The Shawshank Redemption     9.2  1994
# 1                                       The Godfather     9.2  1972
# 2                                     The Dark Knight     9.0  2008
# 3                               The Godfather Part II     9.0  1974
# 4                                        12 Angry Men     8.9  1957
# 5                                    Schindler's List     8.9  1993
# 6         The Lord of the Rings: The Return of the...     8.9  2003
# 7                                        Pulp Fiction     8.8  1994
# 8         The Lord of the Rings: The Fellowship of...     8.8  2001
# 9                      The Good, the Bad and the Ugly     8.8  1966
# 10                                       Forrest Gump     8.8  1994
# 11                                         Fight Club     8.7  1999
# 12                                          Inception     8.7  2010
# ...

# %%
import os
os.chdir("/content/drive/MyDrive/HamoyeInternship/Stage C/Webscrapping")

# %%
data.to_csv("my_scraped_data.csv",index=False)

# %%
data.sort_values(by = "Year", ascending= False)
# Out:
#                                  Movie Names Ratings  Year
# 62                         Top Gun: Maverick     8.4  2022
# 189        Everything Everywhere All at Once     8.1  2022
# 133                  Spider-Man: No Way Home     8.2  2021
# 239                                 Jai Bhim     8.0  2021
# 130                               The Father     8.2  2020
# ..                                       ...     ...   ...
# 114                               Metropolis     8.2  1927
# 185                              The General     8.1  1926
# 174                            The Gold Rush     8.1  1925
# 193                              Sherlock Jr     8.1  1924
# 127                                  The Kid     8.2  1921
#
# [250 rows x 3 columns]

# %%
Top_10_by_Year = data.sort_values(by = "Year", ascending= False).head(10)
Top_10_by_Year
# Out:
#                                  Movie Names Ratings  Year
# 62                         Top Gun: Maverick     8.4  2022
# 189        Everything Everywhere All at Once     8.1  2022
# 133                  Spider-Man: No Way Home     8.2  2021
# 239                                 Jai Bhim     8.0  2021
# 130                               The Father     8.2  2020
# 118                                 Hamilton     8.2  2020
# 196                                    Klaus     8.1  2019
# 34                                  Parasite     8.5  2019
# 79                         Avengers: Endgame     8.3  2019
# 211                           Ford v Ferrari     8.0  2019

# %%
Top_10_by_rating = data.sort_values(by = "Ratings", ascending= False).head(10)
Top_10_by_rating
# Out:
#                                          Movie Names Ratings  Year
# 0                           The Shawshank Redemption     9.2  1994
# 1                                      The Godfather     9.2  1972
# 2                                    The Dark Knight     9.0  2008
# 3                              The Godfather Part II     9.0  1974
# 4                                       12 Angry Men     8.9  1957
# 5                                   Schindler's List     8.9  1993
# 6        The Lord of the Rings: The Return of the...     8.9  2003
# 7                                       Pulp Fiction     8.8  1994
# 8        The Lord of the Rings: The Fellowship of...     8.8  2001
# 9                     The Good, the Bad and the Ugly     8.8  1966

# %%
Top_10_by_Year.plot(x="Year", y="Movie Names", kind="scatter")
Top_10_by_rating.plot(x="Ratings", y="Movie Names", kind="scatter")
plt.title("scatter chart")
plt.subplot(1, 1, 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.

# %% [markdown]
# ##How many movies were made in 2022 and have a rating of >= 8?

# %%
data["Ratings"]= data.Ratings.astype(float)

# %%
data.Ratings.dtype
# Out:
# dtype('float64')

# %%
data["Year"]= data.Year.astype(int)

# %%
data.Year.dtype
# Out:
# dtype('int64')

# %%
data[(data["Ratings"]>= 8 ) & (data["Year"] == 2022)].count()
# Out:
# MovieName    2
# Ratings      2
# Year         2
# dtype: int64

# %%
data[data.Ratings >= 8].count()
# Out:
# MovieName    250
# Ratings      250
# Year         250
# dtype: int64

# %%
Ratings_Group = data.Ratings.unique()
Ratings_Group
# Out:
# array([9.2, 9. , 8.9, 8.8, 8.7, 8.6, 8.5, 8.4, 8.3, 8.2, 8.1, 8. ])

# %%
data.rename(columns = {"Movie Names": "MovieName"}, inplace=True)

# %%
data.head()
# Out:
#                         MovieName  Ratings  Year
# 0        The Shawshank Redemption      9.2  1994
# 1                   The Godfather      9.2  1972
# 2                 The Dark Knight      9.0  2008
# 3           The Godfather Part II      9.0  1974
# 4                    12 Angry Men      8.9  1957

# %%
Ratings_Group = data.groupby("Ratings").MovieName.count()

Ratings_Group
# Out:
# Ratings
# 8.0    40
# 8.1    66
# 8.2    46
# 8.3    33
# 8.4    19
# 8.5    18
# 8.6    11
# 8.7     6
# 8.8     4
# 8.9     3
# 9.0     2
# 9.2     2
# Name: MovieName, dtype: int64

# %%
MostRated_Group = data.groupby("MovieName").Ratings.count()

MostRated_Group
# Out:
# MovieName
#       12 Angry Men                   1
#       12 Years a Slave               1
#       1917                           1
#       2001: A Space Odyssey          1
#       3 Idiots                       1
#                                     ..
#       Wild Strawberries              1
#       Wild Tales                     1
#       Witness for the Prosecution    1
#       Yojimbo                        1
#       Your Name                      1
# Name: Ratings, Length: 250, dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.plot(Ratings_Group, 'g--')
plt.xlabel("Ratings Categories")
plt.ylabel("Number of Movies")
plt.show()

# %% [markdown]
# ##Graph of movies categorized by ratings before 2000 and after 2000

# %%
YearGroups = data.Year.unique()
YearGroups
# Out:
# array([1994, 1972, 2008, 1974, 1957, 1993, 2003, 2001, 1966, 1999, 2010,
#        2002, 1980, 1990, 1975, 1995, 1954, 1946, 1991, 1998, 1997, 2014,
#        1977, 1985, 1960, 2019, 2000, 2006, 1942, 2011, 1962, 1988, 1936,
#        1968, 1979, 1931, 1981, 2012, 1950, 1940, 2022, 2018, 1986, 1964,
#        1984, 2017, 2009, 2016, 1952, 1983, 1963, 2004, 1992, 1941, 1959,
#        1958, 1971, 1944, 1987, 1973, 1976, 1927, 2020, 1989, 1948, 2007,
#        1965, 2005, 1921, 2013, 2021, 1961, 1982, 1939, 2015, 1996, 1925,
#        1949, 1926, 1978, 1953, 1924, 1928, 1955, 1967, 1934])

# %%
YearGroups.min()
# Out:
# 1921

# %%
YearGroups.max()
# Out:
# 2022

# %%
Before2000 = data[(data.Year <= 2000)]
Before2000.count()
# Out:
# MovieName    158
# Ratings      158
# Year         158
# dtype: int64

# %%
After2000 = data[(data.Year > 2000)]

After2000.count()
# Out:
# MovieName    92
# Ratings      92
# Year         92
# dtype: int64

# %%
MoviesBefore2000 = Before2000.groupby('Ratings').MovieName.count()
MoviesBefore2000
# Out:
# Ratings
# 8.0    26
# 8.1    37
# 8.2    29
# 8.3    20
# 8.4    14
# 8.5    11
# 8.6     9
# 8.7     4
# 8.8     3
# 8.9     2
# 9.0     1
# 9.2     2
# Name: MovieName, dtype: int64

# %%
MoviesAfter2000 = After2000.groupby('Ratings').MovieName.count()
MoviesAfter2000
# Out:
# Ratings
# 8.0    14
# 8.1    29
# 8.2    17
# 8.3    13
# 8.4     5
# 8.5     7
# 8.6     2
# 8.7     2
# 8.8     1
# 8.9     1
# 9.0     1
# Name: MovieName, dtype: int64

# %%
plt.plot(MoviesBefore2000, 'r--')
plt.plot(MoviesAfter2000, 'g--')
plt.xlabel("Ratings Categories")
plt.ylabel("Number of Movies")
plt.show()

# %% [markdown]
# ##Graph thesame but showing the percentage of the movies

# %%
percentageBefore2000 = MoviesBefore2000 / sum(MoviesBefore2000)

# %%
percentageAfter2000 = MoviesAfter2000 / sum(MoviesAfter2000)

# %%
plt.plot(percentageBefore2000, 'r--')
plt.plot(percentageAfter2000, 'y--')
plt.xlabel("Ratings Categories")
plt.ylabel("% of Movies")
plt.show()

# %%
Top10_moviesBefore = Before2000.sort_values(by = "Ratings", ascending= False).head(10)
Top10_moviesBefore
# Out:
#                                             MovieName  Ratings  Year
# 0                            The Shawshank Redemption      9.2  1994
# 1                                       The Godfather      9.2  1972
# 3                               The Godfather Part II      9.0  1974
# 5                                    Schindler's List      8.9  1993
# 4                                        12 Angry Men      8.9  1957
# 7                                        Pulp Fiction      8.8  1994
# 9                      The Good, the Bad and the Ugly      8.8  1966
# 10                                       Forrest Gump      8.8  1994
# 11                                         Fight Club      8.7  1999
# 14        Star Wars: Episode V - The Empire Strike...      8.7  1980

# %%
Top10_moviesAfter = After2000.sort_values(by = "Ratings", ascending= False).head(10)
Top10_moviesAfter
# Out:
#                                             MovieName  Ratings  Year
# 2                                     The Dark Knight      9.0  2008
# 6         The Lord of the Rings: The Return of the...      8.9  2003
# 8         The Lord of the Rings: The Fellowship of...      8.8  2001
# 12                                          Inception      8.7  2010
# 13              The Lord of the Rings: The Two Towers      8.7  2002
# 22                                        City of God      8.6  2002
# 26                                       Interstellar      8.6  2014
# 38                                       The Departed      8.5  2006
# 43                                   The Intouchables      8.5  2011
# 40                                       The Prestige      8.5  2006

# %%
Top10_moviesBefore.plot(x="Year", y="MovieName", kind="scatter")
Top10_moviesAfter.plot(x="Year", y="MovieName", kind="scatter")
plt.title("scatter chart")
# plt.subplot(1, 1, 1)
plt.show()

# %%
# sns.catplot(x="Year", y="MovieName", jitter=False, data=Top10_moviesBefore)
# sns.catplot(x="Year", y="MovieName", jitter=False, data=Top10_moviesAfter)

# sns.catplot(x="Year", y="MovieName", kind="swarm", data=Top10_moviesBefore)
# sns.catplot(x="Year", y="MovieName", kind="swarm", data=Top10_moviesAfter)
